# %%
import numpy as np 
import os
import cv2

import keras.backend as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import backend as keras
from keras.metrics import accuracy
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
# %tensorflow_version 2.x

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Create 2 virtual GPUs with 1GB memory each
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=1024),
         tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPU, 2 Logical GPUs

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_logical_devices('GPU')
strategy = tf.distribute.MirroredStrategy(gpus)
with strategy.scope():
  inputs = tf.keras.layers.Input(shape=(1,))
  predictions = tf.keras.layers.Dense(1)(inputs)
  model = tf.keras.models.Model(inputs=inputs, outputs=predictions)
  model.compile(loss='mse',
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.2))
# Out:
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13567314910042872503
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14465892352
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9072163724448735261
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
  return 1-dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(K.abs(y_true_f * y_pred_f))
  union = K.sum(y_true_f)+K.sum(y_pred_f) - intersection
  iou = K.mean((intersection + smooth) / (union + smooth))
  return iou


def fcn_2s(input_size = (256,256,3)):
    
    inputs = Input(input_size)
    x = BatchNormalization()(inputs)
    
    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)
    block_1 = Conv2D(3, (1, 1), activation='relu', padding='same')(x)
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)
    block_2 = Conv2D(3, (1, 1), activation='relu', padding='same')(x)
    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)
    
    block_3 = Conv2D(3, (1, 1), activation='relu', padding='same')(x)
    
    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)
    
    block_4 = Conv2D(3, (1, 1), activation='relu', padding='same')(x)
    
    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)
    
    x = Conv2D(512, (3, 3), activation='relu', padding="same")(x)

    block_5 = Conv2DTranspose(3, kernel_size=(4, 4), strides=(2, 2), activation='relu', padding='same')(x)
    
    sum_1 = add([block_4, block_5])
    sum_1 = Conv2DTranspose(3, kernel_size=(4, 4), strides=(2, 2), activation='relu', padding='same')(sum_1)
    
    sum_2 = add([block_3, sum_1])
    sum_2 = Conv2DTranspose(3, kernel_size=(4, 4), strides=(2, 2), activation='relu', padding='same')(sum_2)
    
    sum_3 = add([block_2, sum_2])
    sum_3 = Conv2DTranspose(3, kernel_size=(4, 4), strides=(2, 2), activation='relu', padding='same')(sum_3) 
    
    sum_4 = add([block_1, sum_3])   
    x = Conv2DTranspose(3, kernel_size=(4, 4), strides=(2, 2), activation='sigmoid', padding='same')(sum_4)
    
    model = Model(inputs = inputs, outputs = x)

    model.compile(optimizer = Adam(learning_rate = 2e-4), loss = 'binary_crossentropy', metrics = [dice_coef, iou_coef])
    
    return model

# %%
def listOfFiles(directory):

    x = []

    for root, dirs, files in os.walk(directory):

        for name in files:

            filename = os.path.join(root, name)

            y = filename.split('\\')

            x.append(y[0])
            
    x.sort()

    return x

# %%
print('*'*30)
print('Loading and preprocessing train data...')
print('*'*30)

path_train = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/train'
path_train_mask = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/train_labels'

img_train_path = listOfFiles(path_train)
img_train_mask_path = listOfFiles(path_train_mask)
img_train = []
mask_train = []

for i in range(1000):
  train_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_train.append(train_im)
  mask_train.append(mask_im)

img_train = np.array(img_train)
img_train = img_train.astype('float32')
img_train /= 255

mask_train = np.array(mask_train)
mask_train = mask_train.astype('float32')
mask_train /= 255
mask_train[mask_train > 0.5] = 1
mask_train[mask_train <= 0.5] = 0

print('*'*30)
print('Complete preprocessing train data...')
print('*'*30)
# Out:
# ******************************
# Loading and preprocessing train data...
# ******************************
# ******************************
# Complete preprocessing train data...
# ******************************

# %%
print('*'*30)
print('Creating and compiling model...')
print('*'*30)
model = fcn_2s()
# Out:
# ******************************
# Creating and compiling model...
# ******************************

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 3)  12         ['input_3[0][0]']
#  rmalization)
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['batch_normalization_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block5_conv3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    2359808     ['block5_pool[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 3)    1539        ['block4_pool[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 16, 16, 3)   24579       ['conv2d_9[0][0]']
#  spose)
#
#  add_4 (Add)                    (None, 16, 16, 3)    0           ['conv2d_8[0][0]',
#                                                                   'conv2d_transpose_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 3)    771         ['block3_pool[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 32, 32, 3)   147         ['add_4[0][0]']
#  spose)
#
#  add_5 (Add)                    (None, 32, 32, 3)    0           ['conv2d_7[0][0]',
#                                                                   'conv2d_transpose_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 3)    387         ['block2_pool[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 64, 64, 3)   147         ['add_5[0][0]']
#  spose)
#
#  add_6 (Add)                    (None, 64, 64, 3)    0           ['conv2d_6[0][0]',
#                                                                   'conv2d_transpose_7[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 3)  195         ['block1_pool[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 128, 128, 3)  147        ['add_6[0][0]']
#  spose)
#
#  add_7 (Add)                    (None, 128, 128, 3)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_transpose_8[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 256, 256, 3)  147        ['add_7[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 17,102,567
# Trainable params: 17,102,561
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %%
def plot_training_history(history):
    """
    Plots model training history 
    """
    fig, (ax_loss, ax_dic, ax_iou) = plt.subplots(1, 3, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_dic.plot(history.epoch, history.history["dice_coef"], label="Train dice")
    ax_dic.plot(history.epoch, history.history["val_dice_coef"], label="Validation dice")
    ax_dic.legend()
    ax_iou.plot(history.epoch, history.history["iou_coef"], label="Train iou")
    ax_iou.plot(history.epoch, history.history["val_iou_coef"], label="Validation iou")
    ax_iou.legend()

# %%
print('*'*30)
print('Fitting model...')
print('*'*30)

epochs = 200
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
model_checkpoint = ModelCheckpoint(f'FCNwithMass_{epochs}epochs.h5', monitor='val_loss', save_best_only=True)

history =  model.fit(img_train, mask_train, batch_size=10, epochs=epochs, verbose=1, shuffle=True,
          validation_split=0.3,
          callbacks=[model_checkpoint, early_stopping])
# Out:
# ******************************
# Fitting model...
# ******************************
# Epoch 1/200
# 70/70 [==============================] - 21s 280ms/step - loss: 0.5865 - dice_coef: 0.0816 - iou_coef: 0.0426 - val_loss: 0.5830 - val_dice_coef: 0.1073 - val_iou_coef: 0.0572
# Epoch 2/200
# 70/70 [==============================] - 19s 270ms/step - loss: 0.4097 - dice_coef: 0.0821 - iou_coef: 0.0429 - val_loss: 0.4093 - val_dice_coef: 0.1079 - val_iou_coef: 0.0574
# Epoch 3/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.2597 - dice_coef: 0.0779 - iou_coef: 0.0406 - val_loss: 0.2749 - val_dice_coef: 0.1040 - val_iou_coef: 0.0550
# Epoch 4/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1954 - dice_coef: 0.0777 - iou_coef: 0.0405 - val_loss: 0.2395 - val_dice_coef: 0.1017 - val_iou_coef: 0.0537
# Epoch 5/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1798 - dice_coef: 0.0809 - iou_coef: 0.0422 - val_loss: 0.2305 - val_dice_coef: 0.0984 - val_iou_coef: 0.0518
# Epoch 6/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1731 - dice_coef: 0.0848 - iou_coef: 0.0443 - val_loss: 0.2272 - val_dice_coef: 0.0985 - val_iou_coef: 0.0518
# Epoch 7/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1692 - dice_coef: 0.0879 - iou_coef: 0.0460 - val_loss: 0.2251 - val_dice_coef: 0.1009 - val_iou_coef: 0.0532
# Epoch 8/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1662 - dice_coef: 0.0916 - iou_coef: 0.0480 - val_loss: 0.2244 - val_dice_coef: 0.1021 - val_iou_coef: 0.0538
# Epoch 9/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.1646 - dice_coef: 0.0949 - iou_coef: 0.0499 - val_loss: 0.2218 - val_dice_coef: 0.1070 - val_iou_coef: 0.0566
# Epoch 10/200
# 70/70 [==============================] - 19s 267ms/step - loss: 0.
200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1047 - dice_coef: 0.3506 - iou_coef: 0.2131 - val_loss: 0.1672 - val_dice_coef: 0.2998 - val_iou_coef: 0.1770
# Epoch 123/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1045 - dice_coef: 0.3514 - iou_coef: 0.2137 - val_loss: 0.1667 - val_dice_coef: 0.3138 - val_iou_coef: 0.1869
# Epoch 124/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1048 - dice_coef: 0.3509 - iou_coef: 0.2134 - val_loss: 0.1653 - val_dice_coef: 0.3139 - val_iou_coef: 0.1868
# Epoch 125/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1044 - dice_coef: 0.3524 - iou_coef: 0.2145 - val_loss: 0.1652 - val_dice_coef: 0.3238 - val_iou_coef: 0.1938
# Epoch 126/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1041 - dice_coef: 0.3538 - iou_coef: 0.2156 - val_loss: 0.1653 - val_dice_coef: 0.3198 - val_iou_coef: 0.1911
# Epoch 127/200
# 70/70 [==============================] - 18s 262ms/step - loss: 0.1044 - dice_coef: 0.3541 - iou_coef: 0.2158 - val_loss: 0.1628 - val_dice_coef: 0.3065 - val_iou_coef: 0.1816
# Epoch 128/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1045 - dice_coef: 0.3527 - iou_coef: 0.2147 - val_loss: 0.1668 - val_dice_coef: 0.3106 - val_iou_coef: 0.1846
# Epoch 129/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1038 - dice_coef: 0.3558 - iou_coef: 0.2169 - val_loss: 0.1638 - val_dice_coef: 0.3160 - val_iou_coef: 0.1882
# Epoch 130/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1039 - dice_coef: 0.3559 - iou_coef: 0.2173 - val_loss: 0.1649 - val_dice_coef: 0.3310 - val_iou_coef: 0.1990
# Epoch 131/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1041 - dice_coef: 0.3574 - iou_coef: 0.2182 - val_loss: 0.1642 - val_dice_coef: 0.3209 - val_iou_coef: 0.1918
# Epoch 132/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.1037 - dice_coef: 0.3565 - iou_coef: 0.2175 - val_loss: 0.1626 - val_dice_coef: 0.3223 - val_iou_coef: 0.1928
# Epoch 133/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1037 - dice_coef: 0.3565 - iou_coef: 0.2177 - val_loss: 0.1633 - val_dice_coef: 0.3286 - val_iou_coef: 0.1973
# Epoch 134/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1032 - dice_coef: 0.3605 - iou_coef: 0.2206 - val_loss: 0.1628 - val_dice_coef: 0.3083 - val_iou_coef: 0.1829
# Epoch 135/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1032 - dice_coef: 0.3612 - iou_coef: 0.2211 - val_loss: 0.1650 - val_dice_coef: 0.3105 - val_iou_coef: 0.1846
# Epoch 136/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1031 - dice_coef: 0.3606 - iou_coef: 0.2208 - val_loss: 0.1651 - val_dice_coef: 0.3116 - val_iou_coef: 0.1853
# Epoch 137/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.1029 - dice_coef: 0.3622 - iou_coef: 0.2218 - val_loss: 0.1625 - val_dice_coef: 0.3128 - val_iou_coef: 0.1861
# Epoch 138/200
# 70/70 [==============================] - 18s 260ms/step - loss: 0.1029 - dice_coef: 0.3623 - iou_coef: 0.2218 - val_loss: 0.1616 - val_dice_coef: 0.3288 - val_iou_coef: 0.1974
# Epoch 139/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1025 - dice_coef: 0.3639 - iou_coef: 0.2231 - val_loss: 0.1650 - val_dice_coef: 0.3301 - val_iou_coef: 0.1985
# Epoch 140/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1025 - dice_coef: 0.3660 - iou_coef: 0.2247 - val_loss: 0.1629 - val_dice_coef: 0.3223 - val_iou_coef: 0.1927
# Epoch 141/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1024 - dice_coef: 0.3672 - iou_coef: 0.2256 - val_loss: 0.1635 - val_dice_coef: 0.3295 - val_iou_coef: 0.1980
# Epoch 142/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1026 - dice_coef: 0.3644 - iou_coef: 0.2239 - val_loss: 0.1624 - val_dice_coef: 0.3279 - val_iou_coef: 0.1969
# Epoch 143/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1025 - dice_coef: 0.3678 - iou_coef: 0.2260 - val_loss: 0.1634 - val_dice_coef: 0.3240 - val_iou_coef: 0.1939
# Epoch 144/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1023 - dice_coef: 0.3672 - iou_coef: 0.2257 - val_loss: 0.1619 - val_dice_coef: 0.3233 - val_iou_coef: 0.1935
# Epoch 145/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1021 - dice_coef: 0.3681 - iou_coef: 0.2261 - val_loss: 0.1639 - val_dice_coef: 0.3251 - val_iou_coef: 0.1949
# Epoch 146/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1018 - dice_coef: 0.3698 - iou_coef: 0.2275 - val_loss: 0.1629 - val_dice_coef: 0.3319 - val_iou_coef: 0.1997
# Epoch 147/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1016 - dice_coef: 0.3716 - iou_coef: 0.2287 - val_loss: 0.1637 - val_dice_coef: 0.3312 - val_iou_coef: 0.1993
# Epoch 148/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.1017 - dice_coef: 0.3713 - iou_coef: 0.2286 - val_loss: 0.1615 - val_dice_coef: 0.3225 - val_iou_coef: 0.1929
# Epoch 149/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1018 - dice_coef: 0.3702 - iou_coef: 0.2280 - val_loss: 0.1620 - val_dice_coef: 0.3180 - val_iou_coef: 0.1897
# Epoch 150/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.1015 - dice_coef: 0.3722 - iou_coef: 0.2293 - val_loss: 0.1603 - val_dice_coef: 0.3301 - val_iou_coef: 0.1983
# Epoch 151/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1022 - dice_coef: 0.3685 - iou_coef: 0.2266 - val_loss: 0.1658 - val_dice_coef: 0.3280 - val_iou_coef: 0.1970
# Epoch 152/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1020 - dice_coef: 0.3727 - iou_coef: 0.2297 - val_loss: 0.1603 - val_dice_coef: 0.3187 - val_iou_coef: 0.1902
# Epoch 153/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1019 - dice_coef: 0.3711 - iou_coef: 0.2284 - val_loss: 0.1622 - val_dice_coef: 0.3253 - val_iou_coef: 0.1949
# Epoch 154/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1011 - dice_coef: 0.3731 - iou_coef: 0.2303 - val_loss: 0.1625 - val_dice_coef: 0.3280 - val_iou_coef: 0.1971
# Epoch 155/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1008 - dice_coef: 0.3772 - iou_coef: 0.2330 - val_loss: 0.1606 - val_dice_coef: 0.3344 - val_iou_coef: 0.2015
# Epoch 156/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1009 - dice_coef: 0.3760 - iou_coef: 0.2323 - val_loss: 0.1624 - val_dice_coef: 0.3402 - val_iou_coef: 0.2056
# Epoch 157/200
# 70/70 [==============================] - 18s 260ms/step - loss: 0.1009 - dice_coef: 0.3775 - iou_coef: 0.2332 - val_loss: 0.1600 - val_dice_coef: 0.3312 - val_iou_coef: 0.1991
# Epoch 158/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1011 - dice_coef: 0.3759 - iou_coef: 0.2321 - val_loss: 0.1621 - val_dice_coef: 0.3286 - val_iou_coef: 0.1973
# Epoch 159/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1005 - dice_coef: 0.3784 - iou_coef: 0.2342 - val_loss: 0.1620 - val_dice_coef: 0.3253 - val_iou_coef: 0.1951
# Epoch 160/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1005 - dice_coef: 0.3790 - iou_coef: 0.2345 - val_loss: 0.1611 - val_dice_coef: 0.3397 - val_iou_coef: 0.2054
# Epoch 161/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1001 - dice_coef: 0.3800 - iou_coef: 0.2352 - val_loss: 0.1617 - val_dice_coef: 0.3371 - val_iou_coef: 0.2035
# Epoch 162/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1003 - dice_coef: 0.3806 - iou_coef: 0.2358 - val_loss: 0.1611 - val_dice_coef: 0.3317 - val_iou_coef: 0.1996
# Epoch 163/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1006 - dice_coef: 0.3797 - iou_coef: 0.2350 - val_loss: 0.1625 - val_dice_coef: 0.3351 - val_iou_coef: 0.2022
# Epoch 164/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.1000 - dice_coef: 0.3833 - iou_coef: 0.2378 - val_loss: 0.1597 - val_dice_coef: 0.3326 - val_iou_coef: 0.2002
# Epoch 165/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1000 - dice_coef: 0.3825 - iou_coef: 0.2371 - val_loss: 0.1611 - val_dice_coef: 0.3366 - val_iou_coef: 0.2031
# Epoch 166/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0998 - dice_coef: 0.3812 - iou_coef: 0.2364 - val_loss: 0.1610 - val_dice_coef: 0.3395 - val_iou_coef: 0.2053
# Epoch 167/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0997 - dice_coef: 0.3845 - iou_coef: 0.2386 - val_loss: 0.1598 - val_dice_coef: 0.3385 - val_iou_coef: 0.2045
# Epoch 168/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1000 - dice_coef: 0.3808 - iou_coef: 0.2359 - val_loss: 0.1605 - val_dice_coef: 0.3341 - val_iou_coef: 0.2014
# Epoch 169/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.1003 - dice_coef: 0.3810 - iou_coef: 0.2363 - val_loss: 0.1653 - val_dice_coef: 0.3332 - val_iou_coef: 0.2008
# Epoch 170/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.1002 - dice_coef: 0.3834 - iou_coef: 0.2378 - val_loss: 0.1612 - val_dice_coef: 0.3331 - val_iou_coef: 0.2007
# Epoch 171/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0997 - dice_coef: 0.3842 - iou_coef: 0.2383 - val_loss: 0.1628 - val_dice_coef: 0.3378 - val_iou_coef: 0.2040
# Epoch 172/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0995 - dice_coef: 0.3850 - iou_coef: 0.2390 - val_loss: 0.1602 - val_dice_coef: 0.3373 - val_iou_coef: 0.2036
# Epoch 173/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0996 - dice_coef: 0.3875 - iou_coef: 0.2411 - val_loss: 0.1603 - val_dice_coef: 0.3189 - val_iou_coef: 0.1904
# Epoch 174/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0994 - dice_coef: 0.3846 - iou_coef: 0.2389 - val_loss: 0.1607 - val_dice_coef: 0.3372 - val_iou_coef: 0.2036
# Epoch 175/200
# 70/70 [==============================] - 18s 261ms/step - loss: 0.0993 - dice_coef: 0.3863 - iou_coef: 0.2402 - val_loss: 0.1590 - val_dice_coef: 0.3312 - val_iou_coef: 0.1992
# Epoch 176/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0994 - dice_coef: 0.3864 - iou_coef: 0.2402 - val_loss: 0.1593 - val_dice_coef: 0.3359 - val_iou_coef: 0.2026
# Epoch 177/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0995 - dice_coef: 0.3850 - iou_coef: 0.2394 - val_loss: 0.1606 - val_dice_coef: 0.3373 - val_iou_coef: 0.2037
# Epoch 178/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0990 - dice_coef: 0.3884 - iou_coef: 0.2416 - val_loss: 0.1603 - val_dice_coef: 0.3444 - val_iou_coef: 0.2089
# Epoch 179/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0992 - dice_coef: 0.3880 - iou_coef: 0.2413 - val_loss: 0.1603 - val_dice_coef: 0.3376 - val_iou_coef: 0.2040
# Epoch 180/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0990 - dice_coef: 0.3893 - iou_coef: 0.2424 - val_loss: 0.1594 - val_dice_coef: 0.3432 - val_iou_coef: 0.2080
# Epoch 181/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0991 - dice_coef: 0.3881 - iou_coef: 0.2416 - val_loss: 0.1598 - val_dice_coef: 0.3351 - val_iou_coef: 0.2021
# Epoch 182/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0986 - dice_coef: 0.3913 - iou_coef: 0.2440 - val_loss: 0.1593 - val_dice_coef: 0.3341 - val_iou_coef: 0.2014
# Epoch 183/200
# 70/70 [==============================] - 18s 262ms/step - loss: 0.0988 - dice_coef: 0.3910 - iou_coef: 0.2437 - val_loss: 0.1587 - val_dice_coef: 0.3386 - val_iou_coef: 0.2046
# Epoch 184/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0985 - dice_coef: 0.3894 - iou_coef: 0.2427 - val_loss: 0.1603 - val_dice_coef: 0.3506 - val_iou_coef: 0.2133
# Epoch 185/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0984 - dice_coef: 0.3918 - iou_coef: 0.2446 - val_loss: 0.1591 - val_dice_coef: 0.3458 - val_iou_coef: 0.2098
# Epoch 186/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0980 - dice_coef: 0.3932 - iou_coef: 0.2455 - val_loss: 0.1600 - val_dice_coef: 0.3451 - val_iou_coef: 0.2093
# Epoch 187/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0988 - dice_coef: 0.3896 - iou_coef: 0.2429 - val_loss: 0.1598 - val_dice_coef: 0.3490 - val_iou_coef: 0.2122
# Epoch 188/200
# 70/70 [==============================] - 18s 262ms/step - loss: 0.0982 - dice_coef: 0.3940 - iou_coef: 0.2462 - val_loss: 0.1583 - val_dice_coef: 0.3392 - val_iou_coef: 0.2051
# Epoch 189/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0985 - dice_coef: 0.3934 - iou_coef: 0.2456 - val_loss: 0.1592 - val_dice_coef: 0.3542 - val_iou_coef: 0.2161
# Epoch 190/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0980 - dice_coef: 0.3946 - iou_coef: 0.2468 - val_loss: 0.1594 - val_dice_coef: 0.3482 - val_iou_coef: 0.2116
# Epoch 191/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0983 - dice_coef: 0.3960 - iou_coef: 0.2475 - val_loss: 0.1594 - val_dice_coef: 0.3403 - val_iou_coef: 0.2060
# Epoch 192/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0984 - dice_coef: 0.3924 - iou_coef: 0.2450 - val_loss: 0.1617 - val_dice_coef: 0.3500 - val_iou_coef: 0.2131
# Epoch 193/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0981 - dice_coef: 0.3970 - iou_coef: 0.2484 - val_loss: 0.1592 - val_dice_coef: 0.3348 - val_iou_coef: 0.2019
# Epoch 194/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0977 - dice_coef: 0.3969 - iou_coef: 0.2482 - val_loss: 0.1583 - val_dice_coef: 0.3483 - val_iou_coef: 0.2117
# Epoch 195/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0978 - dice_coef: 0.3952 - iou_coef: 0.2473 - val_loss: 0.1603 - val_dice_coef: 0.3460 - val_iou_coef: 0.2101
# Epoch 196/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0977 - dice_coef: 0.3974 - iou_coef: 0.2488 - val_loss: 0.1607 - val_dice_coef: 0.3221 - val_iou_coef: 0.1927
# Epoch 197/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0977 - dice_coef: 0.3975 - iou_coef: 0.2487 - val_loss: 0.1595 - val_dice_coef: 0.3606 - val_iou_coef: 0.2209
# Epoch 198/200
# 70/70 [==============================] - 18s 254ms/step - loss: 0.0979 - dice_coef: 0.3975 - iou_coef: 0.2490 - val_loss: 0.1585 - val_dice_coef: 0.3510 - val_iou_coef: 0.2137
# Epoch 199/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0979 - dice_coef: 0.3957 - iou_coef: 0.2476 - val_loss: 0.1596 - val_dice_coef: 0.3372 - val_iou_coef: 0.2037
# Epoch 200/200
# 70/70 [==============================] - 18s 253ms/step - loss: 0.0975 - dice_coef: 0.3980 - iou_coef: 0.2494 - val_loss: 0.1599 - val_dice_coef: 0.3484 - val_iou_coef: 0.2120

# %%
plot_training_history(history)

# %%
print('*'*30)
print('Loading saved weights...')
print('*'*30)
model.load_weights('/content/drive/MyDrive/NIDA/Image_analytics/Project/FCNwithMass_200epochs.h5')

# %%
path_test = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/test'
path_mask_test = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/test_labels'

img_test_path = listOfFiles(path_test)
img_test_mask_path = listOfFiles(path_mask_test)


img_test = []
img_test_mask = []

for i in range(len(img_test_path)):
  test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_test.append(test_im)
  img_test_mask.append(mask_test_im)


img_test = np.array(img_test)
img_test = img_test.astype('float32')
img_test /= 255

img_test_mask = np.array(img_test_mask)
img_test_mask = img_test_mask.astype('float32')
img_test_mask /= 255
img_test_mask[img_test_mask > 0.5] = 1
img_test_mask[img_test_mask <= 0.5] = 0

print('*'*30)
print('Evalute model on test data...')
print('*'*30)

eval = model.evaluate(img_test, img_test_mask)
# Out:
# ******************************
# Evalute model on test data...
# ******************************
# 2/2 [==============================] - 7s 2s/step - loss: 0.0947 - dice_coef: 0.4223 - iou_coef: 0.2680

# %%
path_pred = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/val'
img_pred_path = listOfFiles(path_pred)
img_pred = []

for i in range(len(img_pred_path)):
  pred_im = cv2.resize(cv2.cvtColor(cv2.imread(img_pred_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_pred.append(pred_im)

img_pred = np.array(img_pred)
img_pred = img_pred.astype('float32')
img_pred /= 255

print('*'*30)
print('Predicting masks on test data...')
print('*'*30)
mask_pred = model.predict(img_pred, verbose=1)
# Out:
# ******************************
# Predicting masks on test data...
# ******************************
# 1/1 [==============================] - 2s 2s/step

# %%
path_pred_mask = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/val_labels'
img_pred_mask_path = listOfFiles(path_pred_mask)
img_pred_mask = []

for i in range(len(img_pred_mask_path)):
  pred_mask_im = cv2.resize(cv2.cvtColor(cv2.imread(img_pred_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_pred_mask.append(pred_mask_im)

img_pred_mask = np.array(img_pred_mask)
img_pred_mask = img_pred_mask.astype('float32')
img_pred_mask /= 255

# %%
plt.imshow(mask_pred[4])

# %%
plt.imshow(img_pred_mask[4])

# %%
plt.imshow(img_pred[4])
