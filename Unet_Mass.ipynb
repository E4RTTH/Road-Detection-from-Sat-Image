# %%
import numpy as np 
import os
import cv2

import keras.backend as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import backend as keras
from keras.metrics import accuracy
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
# %tensorflow_version 2.x

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Create 2 virtual GPUs with 1GB memory each
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=1024),
         tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPU, 2 Logical GPUs

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_logical_devices('GPU')
strategy = tf.distribute.MirroredStrategy(gpus)
with strategy.scope():
  inputs = tf.keras.layers.Input(shape=(1,))
  predictions = tf.keras.layers.Dense(1)(inputs)
  model = tf.keras.models.Model(inputs=inputs, outputs=predictions)
  model.compile(loss='mse',
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.2))
# Out:
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12609722189929681617
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 16154099712
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10481245919476024474
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# xla_global_id: 416903419
# ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
  return 1-dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(K.abs(y_true_f * y_pred_f))
  union = K.sum(y_true_f)+K.sum(y_pred_f) - intersection
  iou = K.mean((intersection + smooth) / (union + smooth))
  return iou


def unet(input_size = (256, 256, 3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', 
                                               kernel_initializer = 'he_normal'
                                               )(inputs)
    
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', 
                                               kernel_initializer = 'he_normal'
                                               )(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool1)
    
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool2)
    
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv3)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool3)
    
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(conv4)
    
    drop4 = Dropout(0.5)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', 
                                                 kernel_initializer = 'he_normal'
                                                 )(pool4)
    
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', 
                                                 kernel_initializer = 'he_normal'
                                                 )(conv5)
    
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', 
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(drop5))
    
    merge6 = concatenate([drop4,up6])
    
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge6)
    
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(conv6))
    
    merge7 = concatenate([conv3,up7])
    
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge7)
    
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'
                                                )(conv7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(conv7))
    
    merge8 = concatenate([conv2,up8])
    
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge8)
    
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same',
                                             kernel_initializer = 'he_normal'
                                             )(UpSampling2D(size = (2,2))(conv8))
    
    merge9 = concatenate([conv1,up9])
    
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same',
                                               kernel_initializer = 'he_normal'
                                               )(merge9)
    
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same',
                                               kernel_initializer = 'he_normal'
                                               )(conv9)
    
    conv9 = Conv2D(3, 3, activation = 'sigmoid', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(conv9)
    
    # conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv9)

    model.compile(optimizer = Adam(learning_rate = 0.002), loss = 'binary_crossentropy', metrics = [dice_coef, iou_coef])

    
    return model

# %%
def listOfFiles(directory):

    x = []

    for root, dirs, files in os.walk(directory):

        for name in files:

            filename = os.path.join(root, name)

            y = filename.split('\\')

            x.append(y[0])
            
    x.sort()

    return x

# %%
print('*'*30)
print('Loading and preprocessing train data...')
print('*'*30)

path_train = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/train'
path_train_mask = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/train_labels'

img_train_path = listOfFiles(path_train)
img_train_mask_path = listOfFiles(path_train_mask)
img_train = []
mask_train = []

for i in range(1000):
  train_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_train.append(train_im)
  mask_train.append(mask_im)

img_train = np.array(img_train)
img_train = img_train.astype('float32')
img_train /= 255

mask_train = np.array(mask_train)
mask_train = mask_train.astype('float32')
mask_train /= 255
mask_train[mask_train > 0.5] = 1
mask_train[mask_train <= 0.5] = 0

print('*'*30)
print('Complete preprocessing train data...')
print('*'*30)
# Out:
# ******************************
# Loading and preprocessing train data...
# ******************************
# ******************************
# Complete preprocessing train data...
# ******************************

# %%
print('*'*30)
print('Creating and compiling model...')
print('*'*30)
model = unet()
# Out:
# ******************************
# Creating and compiling model...
# ******************************

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_2[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['conv2d_8[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 16, 16, 1024  0           ['conv2d_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1024  0           ['dropout_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2097664     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['dropout[0][0]',
#                                 )                                 'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  524544      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_15[0][0]']
#                                 6)
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 12  131200      ['up_sampling2d_2[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_3[0][0]',
#                                 6)                                'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_17[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_18[0][0]']
#                                 8)
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  32832       ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 3)  1731        ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 31,033,411
# Trainable params: 31,033,411
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def plot_training_history(history):
    """
    Plots model training history 
    """
    fig, (ax_loss, ax_dic, ax_iou) = plt.subplots(1, 3, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.set_ylim([0, 0.5])
    ax_loss.legend()
    ax_dic.plot(history.epoch, history.history["dice_coef"], label="Train dice")
    ax_dic.plot(history.epoch, history.history["val_dice_coef"], label="Validation dice")
    ax_dic.legend()
    ax_iou.plot(history.epoch, history.history["iou_coef"], label="Train iou")
    ax_iou.plot(history.epoch, history.history["val_iou_coef"], label="Validation iou")
    ax_iou.legend()

# %%
print('*'*30)
print('Fitting model...')
print('*'*30)

epochs = 200
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
model_checkpoint = ModelCheckpoint(f'UnetwithMass_{epochs}epochs.h5', monitor='loss', save_best_only=True)

history =  model.fit(img_train, mask_train, batch_size=15, epochs=epochs, verbose=1, shuffle=True,
          validation_split=0.3,
          callbacks=[model_checkpoint, early_stopping])
# Out:
# ******************************
# Fitting model...
# ******************************
# Epoch 1/200
# 47/47 [==============================] - 46s 646ms/step - loss: 1207.5533 - dice_coef: 0.0424 - iou_coef: 0.0218 - val_loss: 0.2841 - val_dice_coef: 0.0677 - val_iou_coef: 0.0352
# Epoch 2/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1871 - dice_coef: 0.0558 - iou_coef: 0.0288 - val_loss: 0.2516 - val_dice_coef: 0.0455 - val_iou_coef: 0.0233
# Epoch 3/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1666 - dice_coef: 0.0735 - iou_coef: 0.0382 - val_loss: 0.2302 - val_dice_coef: 0.0728 - val_iou_coef: 0.0378
# Epoch 4/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1639 - dice_coef: 0.0811 - iou_coef: 0.0423 - val_loss: 0.2334 - val_dice_coef: 0.0706 - val_iou_coef: 0.0366
# Epoch 5/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1622 - dice_coef: 0.0870 - iou_coef: 0.0456 - val_loss: 0.2147 - val_dice_coef: 0.1049 - val_iou_coef: 0.0554
# Epoch 6/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1589 - dice_coef: 0.0943 - iou_coef: 0.0495 - val_loss: 0.2128 - val_dice_coef: 0.1064 - val_iou_coef: 0.0562
# Epoch 7/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1553 - dice_coef: 0.1029 - iou_coef: 0.0543 - val_loss: 0.2076 - val_dice_coef: 0.1258 - val_iou_coef: 0.0672
# Epoch 8/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1504 - dice_coef: 0.1238 - iou_coef: 0.0661 - val_loss: 0.2094 - val_dice_coef: 0.1313 - val_iou_coef: 0.0704
# Epoch 9/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1460 - dice_coef: 0.1415 - iou_coef: 0.0762 - val_loss: 0.2038 - val_dice_coef: 0.1562 - val_iou_coef: 0.0848
# Epoch 10/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1435 - dice_coef: 0.1535 - iou_coef: 0.0832 - val_loss: 0.2042 - val_dice_coef: 0.1660 - val_iou_coef: 0.0906
# Epoch 11/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1427 - dice_coef: 0.1615 - iou_coef: 0.0879 - val_loss: 0.2059 - val_dice_coef: 0.1618 - val_iou_coef: 0.0881
# Epoch 12/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1402 - dice_coef: 0.1704 - iou_coef: 0.0932 - val_loss: 0.1999 - val_dice_coef: 0.1725 - val_iou_coef: 0.0945
# Epoch 13/200
# 47/47 [==============================] - 27s 584ms/step - loss: 0.1400 - dice_coef: 0.1733 - iou_coef: 0.0949 - val_loss: 0.2034 - val_dice_coef: 0.1551 - val_iou_coef: 0.0842
# Epoch 14/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1386 - dice_coef: 0.1772 - iou_coef: 0.0973 - val_loss: 0.2039 - val_dice_coef: 0.1730 - val_iou_coef: 0.0948
# Epoch 15/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1373 - dice_coef: 0.1845 - iou_coef: 0.1017 - val_loss: 0.2013 - val_dice_coef: 0.1704 - val_iou_coef: 0.0932
# Epoch 16/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1389 - dice_coef: 0.1831 - iou_coef: 0.1008 - val_loss: 0.1989 - val_dice_coef: 0.1875 - val_iou_coef: 0.1036
# Epoch 17/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1369 - dice_coef: 0.1890 - iou_coef: 0.1045 - val_loss: 0.1997 - val_dice_coef: 0.1765 - val_iou_coef: 0.0970
# Epoch 18/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1359 - dice_coef: 0.1908 - iou_coef: 0.1056 - val_loss: 0.2008 - val_dice_coef: 0.1803 - val_iou_coef: 0.0992
# Epoch 19/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1349 - dice_coef: 0.1965 - iou_coef: 0.1090 - val_loss: 0.1966 - val_dice_coef: 0.1836 - val_iou_coef: 0.1012
# Epoch 20/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1359 - dice_coef: 0.1957 - iou_coef: 0.1086 - val_loss: 0.1965 - val_dice_coef: 0.1902 - val_iou_coef: 0.1052
# Epoch 21/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1343 - dice_coef: 0.2016 - iou_coef: 0.1122 - val_loss: 0.1962 - val_dice_coef: 0.1940 - val_iou_coef: 0.1075
# Epoch 22/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1339 - dice_coef: 0.2029 - iou_coef: 0.1130 - val_loss: 0.1968 - val_dice_coef: 0.1972 - val_iou_coef: 0.1095
# Epoch 23/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1345 - dice_coef: 0.2031 - iou_coef: 0.1132 - val_loss: 0.1952 - val_dice_coef: 0.1952 - val_iou_coef: 0.1083
# Epoch 24/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1328 - dice_coef: 0.2105 - iou_coef: 0.1177 - val_loss: 0.1964 - val_dice_coef: 0.1946 - val_iou_coef: 0.1079
# Epoch 25/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1335 - dice_coef: 0.2092 - iou_coef: 0.1170 - val_loss: 0.2026 - val_dice_coef: 0.1849 - val_iou_coef: 0.1020
# Epoch 26/200
# 47/47 [==============================] - 27s 583ms/step - loss: 0.1323 - dice_coef: 0.2142 - iou_coef: 0.1201 - val_loss: 0.1935 - val_dice_coef: 0.2112 - val_iou_coef: 0.1182
# Epoch 27/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1307 - dice_coef: 0.2196 - iou_coef: 0.1235 - val_loss: 0.1930 - val_dice_coef: 0.2110 - val_iou_coef: 0.1181
# Epoch 28/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1305 - dice_coef: 0.2218 - iou_coef: 0.1249 - val_loss: 0.1942 - val_dice_coef: 0.2096 - val_iou_coef: 0.1173
# Epoch 29/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1300 - dice_coef: 0.2270 - iou_coef: 0.1281 - val_loss: 0.1989 - val_dice_coef: 0.1908 - val_iou_coef: 0.1056
# Epoch 30/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1317 - dice_coef: 0.2239 - iou_coef: 0.1262 - val_loss: 0.1941 - val_dice_coef: 0.2104 - val_iou_coef: 0.1177
# Epoch 31/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1324 - dice_coef: 0.2209 - iou_coef: 0.1244 - val_loss: 0.1930 - val_dice_coef: 0.2042 - val_iou_coef: 0.1138
# Epoch 32/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1282 - dice_coef: 0.2362 - iou_coef: 0.1341 - val_loss: 0.1898 - val_dice_coef: 0.2181 - val_iou_coef: 0.1225
# Epoch 33/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1272 - dice_coef: 0.2409 - iou_coef: 0.1371 - val_loss: 0.1908 - val_dice_coef: 0.2210 - val_iou_coef: 0.1244
# Epoch 34/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1265 - dice_coef: 0.2446 - iou_coef: 0.1395 - val_loss: 0.1913 - val_dice_coef: 0.2027 - val_iou_coef: 0.1130
# Epoch 35/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1270 - dice_coef: 0.2445 - iou_coef: 0.1396 - val_loss: 0.1950 - val_dice_coef: 0.2070 - val_iou_coef: 0.1159
# Epoch 36/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1297 - dice_coef: 0.2341 - iou_coef: 0.1330 - val_loss: 0.1914 - val_dice_coef: 0.2019 - val_iou_coef: 0.1125
# Epoch 37/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1263 - dice_coef: 0.2477 - iou_coef: 0.1416 - val_loss: 0.1897 - val_dice_coef: 0.2261 - val_iou_coef: 0.1277
# Epoch 38/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1251 - dice_coef: 0.2536 - iou_coef: 0.1455 - val_loss: 0.1972 - val_dice_coef: 0.2054 - val_iou_coef: 0.1148
# Epoch 39/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1280 - dice_coef: 0.2439 - iou_coef: 0.1391 - val_loss: 0.1928 - val_dice_coef: 0.2348 - val_iou_coef: 0.1333
# Epoch 40/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1259 - dice_coef: 0.2534 - iou_coef: 0.1454 - val_loss: 0.1894 - val_dice_coef: 0.2208 - val_iou_coef: 0.1244
# Epoch 41/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1240 - dice_coef: 0.2605 - iou_coef: 0.1499 - val_loss: 0.1868 - val_dice_coef: 0.2283 - val_iou_coef: 0.1291
# Epoch 42/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1252 - dice_coef: 0.2578 - iou_coef: 0.1482 - val_loss: 0.1950 - val_dice_coef: 0.1821 - val_iou_coef: 0.1003
# Epoch 43/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1245 - dice_coef: 0.2585 - iou_coef: 0.1487 - val_loss: 0.1882 - val_dice_coef: 0.2357 - val_iou_coef: 0.1340
# Epoch 44/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1239 - dice_coef: 0.2625 - iou_coef: 0.1514 - val_loss: 0.1871 - val_dice_coef: 0.2290 - val_iou_coef: 0.1295
# Epoch 45/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1242 - dice_coef: 0.2642 - iou_coef: 0.1524 - val_loss: 0.1861 - val_dice_coef: 0.2387 - val_iou_coef: 0.1357
# Epoch 46/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1236 - dice_coef: 0.2663 - iou_coef: 0.1538 - val_loss: 0.1868 - val_dice_coef: 0.2280 - val_iou_coef: 0.1289
# Epoch 47/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1221 - dice_coef: 0.2709 - iou_coef: 0.1569 - val_loss: 0.1855 - val_dice_coef: 0.2406 - val_iou_coef: 0.1370
# Epoch 48/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1225 - dice_coef: 0.2739 - iou_coef: 0.1589 - val_loss: 0.1850 - val_dice_coef: 0.2435 - val_iou_coef: 0.1389
# Epoch 49/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1215 - dice_coef: 0.2764 - iou_coef: 0.1606 - val_loss: 0.1830 - val_dice_coef: 0.2457 - val_iou_coef: 0.1403
# Epoch 50/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1216 - dice_coef: 0.2767 - iou_coef: 0.1608 - val_loss: 0.1873 - val_dice_coef: 0.2457 - val_iou_coef: 0.1403
# Epoch 51/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1220 - dice_coef: 0.2769 - iou_coef: 0.1609 - val_loss: 0.1858 - val_dice_coef: 0.2399 - val_iou_coef: 0.1367
# Epoch 52/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1203 - dice_coef: 0.2846 - iou_coef: 0.1663 - val_loss: 0.1825 - val_dice_coef: 0.2427 - val_iou_coef: 0.1384
# Epoch 53/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1212 - dice_coef: 0.2842 - iou_coef: 0.1659 - val_loss: 0.1836 - val_dice_coef: 0.2566 - val_iou_coef: 0.1474
# Epoch 54/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1218 - dice_coef: 0.2801 - iou_coef: 0.1631 - val_loss: 0.1836 - val_dice_coef: 0.2411 - val_iou_coef: 0.1373
# Epoch 55/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1196 - dice_coef: 0.2902 - iou_coef: 0.1699 - val_loss: 0.1812 - val_dice_coef: 0.2574 - val_iou_coef: 0.1480
# Epoch 56/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1205 - dice_coef: 0.2874 - iou_coef: 0.1682 - val_loss: 0.1848 - val_dice_coef: 0.2486 - val_iou_coef: 0.1424
# Epoch 57/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1198 - dice_coef: 0.2908 - iou_coef: 0.1704 - val_loss: 0.1845 - val_dice_coef: 0.2605 - val_iou_coef: 0.1500
# Epoch 58/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1200 - dice_coef: 0.2921 - iou_coef: 0.1713 - val_loss: 0.1866 - val_dice_coef: 0.2544 - val_iou_coef: 0.1462
# Epoch 59/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1201 - dice_coef: 0.2919 - iou_coef: 0.1713 - val_loss: 0.1820 - val_dice_coef: 0.2563 - val_iou_coef: 0.1474
# Epoch 60/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1190 - dice_coef: 0.2960 - iou_coef: 0.1741 - val_loss: 0.1836 - val_dice_coef: 0.2805 - val_iou_coef: 0.1636
# Epoch 61/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1181 - dice_coef: 0.3027 - iou_coef: 0.1789 - val_loss: 0.1795 - val_dice_coef: 0.2632 - val_iou_coef: 0.1518
# Epoch 62/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1184 - dice_coef: 0.3006 - iou_coef: 0.1772 - val_loss: 0.1806 - val_dice_coef: 0.2683 - val_iou_coef: 0.1552
# Epoch 63/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1178 - dice_coef: 0.3044 - iou_coef: 0.1800 - val_loss: 0.1797 - val_dice_coef: 0.2601 - val_iou_coef: 0.1497
# Epoch 64/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1179 - dice_coef: 0.3052 - iou_coef: 0.1804 - val_loss: 0.1794 - val_dice_coef: 0.2712 - val_iou_coef: 0.1572
# Epoch 65/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1170 - dice_coef: 0.3104 - iou_coef: 0.1840 - val_loss: 0.1795 - val_dice_coef: 0.2740 - val_iou_coef: 0.1591
# Epoch 66/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1163 - dice_coef: 0.3128 - iou_coef: 0.1857 - val_loss: 0.1897 - val_dice_coef: 0.2323 - val_iou_coef: 0.1320
# Epoch 67/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1178 - dice_coef: 0.3075 - iou_coef: 0.1820 - val_loss: 0.1821 - val_dice_coef: 0.2593 - val_iou_coef: 0.1493
# Epoch 68/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1170 - dice_coef: 0.3110 - iou_coef: 0.1844 - val_loss: 0.1786 - val_dice_coef: 0.2804 - val_iou_coef: 0.1635
# Epoch 69/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1158 - dice_coef: 0.3157 - iou_coef: 0.1877 - val_loss: 0.1797 - val_dice_coef: 0.2764 - val_iou_coef: 0.1608
# Epoch 70/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1168 - dice_coef: 0.3126 - iou_coef: 0.1857 - val_loss: 0.1808 - val_dice_coef: 0.2568 - val_iou_coef: 0.1476
# Epoch 71/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1169 - dice_coef: 0.3128 - iou_coef: 0.1858 - val_loss: 0.1875 - val_dice_coef: 0.2686 - val_iou_coef: 0.1559
# Epoch 72/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1175 - dice_coef: 0.3120 - iou_coef: 0.1853 - val_loss: 0.1878 - val_dice_coef: 0.2566 - val_iou_coef: 0.1475
# Epoch 73/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1161 - dice_coef: 0.3191 - iou_coef: 0.1902 - val_loss: 0.1779 - val_dice_coef: 0.2925 - val_iou_coef: 0.1718
# Epoch 74/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1182 - dice_coef: 0.3092 - iou_coef: 0.1833 - val_loss: 0.1841 - val_dice_coef: 0.2739 - val_iou_coef: 0.1593
# Epoch 75/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1160 - dice_coef: 0.3200 - iou_coef: 0.1909 - val_loss: 0.1796 - val_dice_coef: 0.2781 - val_iou_coef: 0.1619
# Epoch 76/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1147 - dice_coef: 0.3232 - iou_coef: 0.1935 - val_loss: 0.1787 - val_dice_coef: 0.2795 - val_iou_coef: 0.1629
# Epoch 77/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1155 - dice_coef: 0.3226 - iou_coef: 0.1928 - val_loss: 0.1796 - val_dice_coef: 0.2700 - val_iou_coef: 0.1565
# Epoch 78/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1146 - dice_coef: 0.3243 - iou_coef: 0.1942 - val_loss: 0.1806 - val_dice_coef: 0.2771 - val_iou_coef: 0.1614
# Epoch 79/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1137 - dice_coef: 0.3311 - iou_coef: 0.1987 - val_loss: 0.1746 - val_dice_coef: 0.2772 - val_iou_coef: 0.1612
# Epoch 80/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1142 - dice_coef: 0.3281 - iou_coef: 0.1966 - val_loss: 0.1767 - val_dice_coef: 0.2688 - val_iou_coef: 0.1557
# Epoch 81/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1136 - dice_coef: 0.3305 - iou_coef: 0.1984 - val_loss: 0.1783 - val_dice_coef: 0.2784 - val_iou_coef: 0.1623
# Epoch 82/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1138 - dice_coef: 0.3286 - iou_coef: 0.1970 - val_loss: 0.1801 - val_dice_coef: 0.2983 - val_iou_coef: 0.1758
# Epoch 83/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1140 - dice_coef: 0.3311 - iou_coef: 0.1989 - val_loss: 0.1744 - val_dice_coef: 0.2649 - val_iou_coef: 0.1530
# Epoch 84/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1147 - dice_coef: 0.3302 - iou_coef: 0.1980 - val_loss: 0.1794 - val_dice_coef: 0.2861 - val_iou_coef: 0.1676
# Epoch 85/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1142 - dice_coef: 0.3290 - iou_coef: 0.1974 - val_loss: 0.1840 - val_dice_coef: 0.2692 - val_iou_coef: 0.1563
# Epoch 86/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1133 - dice_coef: 0.3321 - iou_coef: 0.1996 - val_loss: 0.1769 - val_dice_coef: 0.2947 - val_iou_coef: 0.1731
# Epoch 87/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1137 - dice_coef: 0.3342 - iou_coef: 0.2010 - val_loss: 0.1753 - val_dice_coef: 0.2900 - val_iou_coef: 0.1701
# Epoch 88/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1128 - dice_coef: 0.3347 - iou_coef: 0.2014 - val_loss: 0.1887 - val_dice_coef: 0.2599 - val_iou_coef: 0.1501
# Epoch 89/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1148 - dice_coef: 0.3314 - iou_coef: 0.1990 - val_loss: 0.1740 - val_dice_coef: 0.2728 - val_iou_coef: 0.1582
# Epoch 90/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1130 - dice_coef: 0.3343 - iou_coef: 0.2011 - val_loss: 0.1835 - val_dice_coef: 0.2657 - val_iou_coef: 0.1538
# Epoch 91/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1131 - dice_coef: 0.3369 - iou_coef: 0.2030 - val_loss: 0.1743 - val_dice_coef: 0.2913 - val_iou_coef: 0.1708
# Epoch 92/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1122 - dice_coef: 0.3418 - iou_coef: 0.2067 - val_loss: 0.1753 - val_dice_coef: 0.3092 - val_iou_coef: 0.1834
# Epoch 93/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1122 - dice_coef: 0.3399 - iou_coef: 0.2053 - val_loss: 0.1775 - val_dice_coef: 0.2954 - val_iou_coef: 0.1739
# Epoch 94/200
# 47/47 [==============================] - 27s 579ms/step - loss: 0.1115 - dice_coef: 0.3442 - iou_coef: 0.2085 - val_loss: 0.1736 - val_dice_coef: 0.3002 - val_iou_coef: 0.1771
# Epoch 95/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1129 - dice_coef: 0.3382 - iou_coef: 0.2039 - val_loss: 0.1760 - val_dice_coef: 0.3070 - val_iou_coef: 0.1819
# Epoch 96/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1116 - dice_coef: 0.3454 - iou_coef: 0.2091 - val_loss: 0.1740 - val_dice_coef: 0.3096 - val_iou_coef: 0.1836
# Epoch 97/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1112 - dice_coef: 0.3460 - iou_coef: 0.2097 - val_loss: 0.1773 - val_dice_coef: 0.2907 - val_iou_coef: 0.1706
# Epoch 98/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.1114 - dice_coef: 0.3452 - iou_coef: 0.2090 - val_loss: 0.1753 - val_dice_coef: 0.3030 - val_iou_coef: 0.1792
# Epoch 99/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1107 - dice_coef: 0.3504 - iou_coef: 0.2127 - val_loss: 0.1739 - val_dice_coef: 0.3127 - val_iou_coef: 0.1858
# Epoch 100/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1104 - dice_coef: 0.3507 - iou_coef: 0.2130 - val_loss: 0.1719 - val_dice_coef: 0.3013 - val_iou_coef: 0.1778
# Epoch 101/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1110 - dice_coef: 0.3490 - iou_coef: 0.2120 - val_loss: 0.1749 - val_dice_coef: 0.2836 - val_iou_coef: 0.1657
# Epoch 102/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1103 - dice_coef: 0.3501 - iou_coef: 0.2127 - val_loss: 0.1778 - val_dice_coef: 0.3188 - val_iou_coef: 0.1904
# Epoch 103/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1098 - dice_coef: 0.3554 - iou_coef: 0.2164 - val_loss: 0.1721 - val_dice_coef: 0.3133 - val_iou_coef: 0.1863
# Epoch 104/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1109 - dice_coef: 0.3472 - iou_coef: 0.2106 - val_loss: 0.1755 - val_dice_coef: 0.2976 - val_iou_coef: 0.1753
# Epoch 105/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1111 - dice_coef: 0.3493 - iou_coef: 0.2121 - val_loss: 0.1710 - val_dice_coef: 0.3121 - val_iou_coef: 0.1854
# Epoch 106/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1097 - dice_coef: 0.3531 - iou_coef: 0.2150 - val_loss: 0.1716 - val_dice_coef: 0.3045 - val_iou_coef: 0.1800
# Epoch 107/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1097 - dice_coef: 0.3541 - iou_coef: 0.2157 - val_loss: 0.1711 - val_dice_coef: 0.3134 - val_iou_coef: 0.1862
# Epoch 108/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1093 - dice_coef: 0.3590 - iou_coef: 0.2192 - val_loss: 0.1710 - val_dice_coef: 0.3208 - val_iou_coef: 0.1915
# Epoch 109/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1094 - dice_coef: 0.3578 - iou_coef: 0.2183 - val_loss: 0.1721 - val_dice_coef: 0.3098 - val_iou_coef: 0.1837
# Epoch 110/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1086 - dice_coef: 0.3608 - iou_coef: 0.2205 - val_loss: 0.1741 - val_dice_coef: 0.3158 - val_iou_coef: 0.1881
# Epoch 111/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1101 - dice_coef: 0.3573 - iou_coef: 0.2181 - val_loss: 0.1694 - val_dice_coef: 0.3185 - val_iou_coef: 0.1899
# Epoch 112/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1089 - dice_coef: 0.3591 - iou_coef: 0.2191 - val_loss: 0.1689 - val_dice_coef: 0.3067 - val_iou_coef: 0.1816
# Epoch 113/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1084 - dice_coef: 0.3619 - iou_coef: 0.2213 - val_loss: 0.1775 - val_dice_coef: 0.2850 - val_iou_coef: 0.1666
# Epoch 114/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1092 - dice_coef: 0.3610 - iou_coef: 0.2206 - val_loss: 0.1731 - val_dice_coef: 0.3036 - val_iou_coef: 0.1794
# Epoch 115/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1086 - dice_coef: 0.3626 - iou_coef: 0.2222 - val_loss: 0.1707 - val_dice_coef: 0.3202 - val_iou_coef: 0.1912
# Epoch 116/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1079 - dice_coef: 0.3658 - iou_coef: 0.2245 - val_loss: 0.1713 - val_dice_coef: 0.3188 - val_iou_coef: 0.1900
# Epoch 117/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1085 - dice_coef: 0.3638 - iou_coef: 0.2229 - val_loss: 0.1713 - val_dice_coef: 0.3267 - val_iou_coef: 0.1958
# Epoch 118/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1077 - dice_coef: 0.3655 - iou_coef: 0.2242 - val_loss: 0.1701 - val_dice_coef: 0.3309 - val_iou_coef: 0.1988
# Epoch 119/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1074 - dice_coef: 0.3723 - iou_coef: 0.2291 - val_loss: 0.1682 - val_dice_coef: 0.3105 - val_iou_coef: 0.1843
# Epoch 120/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1071 - dice_coef: 0.3732 - iou_coef: 0.2300 - val_loss: 0.1662 - val_dice_coef: 0.3177 - val_iou_coef: 0.1893
# Epoch 121/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1070 - dice_coef: 0.3761 - iou_coef: 0.2321 - val_loss: 0.1731 - val_dice_coef: 0.3337 - val_iou_coef: 0.2012
# Epoch 122/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1067 - dice_coef: 0.3755 - iou_coef: 0.2318 - val_loss: 0.1842 - val_dice_coef: 0.3377 - val_iou_coef: 0.2046
# Epoch 123/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1068 - dice_coef: 0.3763 - iou_coef: 0.2324 - val_loss: 0.1728 - val_dice_coef: 0.3237 - val_iou_coef: 0.1940
# Epoch 124/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.1058 - dice_coef: 0.3832 - iou_coef: 0.2374 - val_loss: 0.1717 - val_dice_coef: 0.3428 - val_iou_coef: 0.2078
# Epoch 125/200
# 47/47 [==============================] - 27s 583ms/step - loss: 0.1053 - dice_coef: 0.3869 - iou_coef: 0.2404 - val_loss: 0.1658 - val_dice_coef: 0.3249 - val_iou_coef: 0.1944
# Epoch 126/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.1053 - dice_coef: 0.3861 - iou_coef: 0.2399 - val_loss: 0.1701 - val_dice_coef: 0.3286 - val_iou_coef: 0.1975
# Epoch 127/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.1034 - dice_coef: 0.3952 - iou_coef: 0.2469 - val_loss: 0.1653 - val_dice_coef: 0.3309 - val_iou_coef: 0.1987
# Epoch 128/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.1039 - dice_coef: 0.3965 - iou_coef: 0.2476 - val_loss: 0.1678 - val_dice_coef: 0.3171 - val_iou_coef: 0.1889
# Epoch 129/200
# 47/47 [==============================] - 29s 622ms/step - loss: 0.1022 - dice_coef: 0.4036 - iou_coef: 0.2533 - val_loss: 0.1705 - val_dice_coef: 0.3610 - val_iou_coef: 0.2213
# Epoch 130/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.1025 - dice_coef: 0.4032 - iou_coef: 0.2530 - val_loss: 0.1616 - val_dice_coef: 0.3359 - val_iou_coef: 0.2023
# Epoch 131/200
# 47/47 [==============================] - 27s 584ms/step - loss: 0.1019 - dice_coef: 0.4057 - iou_coef: 0.2551 - val_loss: 0.1633 - val_dice_coef: 0.3432 - val_iou_coef: 0.2077
# Epoch 132/200
# 47/47 [==============================] - 27s 579ms/step - loss: 0.1007 - dice_coef: 0.4136 - iou_coef: 0.2612 - val_loss: 0.1600 - val_dice_coef: 0.3612 - val_iou_coef: 0.2210
# Epoch 133/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0997 - dice_coef: 0.4194 - iou_coef: 0.2660 - val_loss: 0.1606 - val_dice_coef: 0.3627 - val_iou_coef: 0.2221
# Epoch 134/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0990 - dice_coef: 0.4228 - iou_coef: 0.2689 - val_loss: 0.1632 - val_dice_coef: 0.3644 - val_iou_coef: 0.2234
# Epoch 135/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0993 - dice_coef: 0.4210 - iou_coef: 0.2675 - val_loss: 0.1631 - val_dice_coef: 0.3689 - val_iou_coef: 0.2270
# Epoch 136/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0987 - dice_coef: 0.4261 - iou_coef: 0.2713 - val_loss: 0.1654 - val_dice_coef: 0.3623 - val_iou_coef: 0.2220
# Epoch 137/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0976 - dice_coef: 0.4341 - iou_coef: 0.2778 - val_loss: 0.1661 - val_dice_coef: 0.3725 - val_iou_coef: 0.2299
# Epoch 138/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0975 - dice_coef: 0.4333 - iou_coef: 0.2773 - val_loss: 0.1614 - val_dice_coef: 0.3675 - val_iou_coef: 0.2260
# Epoch 139/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0972 - dice_coef: 0.4380 - iou_coef: 0.2811 - val_loss: 0.1594 - val_dice_coef: 0.3603 - val_iou_coef: 0.2203
# Epoch 140/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0970 - dice_coef: 0.4359 - iou_coef: 0.2792 - val_loss: 0.1619 - val_dice_coef: 0.3838 - val_iou_coef: 0.2382
# Epoch 141/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0960 - dice_coef: 0.4440 - iou_coef: 0.2865 - val_loss: 0.1594 - val_dice_coef: 0.3832 - val_iou_coef: 0.2379
# Epoch 142/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0955 - dice_coef: 0.4439 - iou_coef: 0.2859 - val_loss: 0.1546 - val_dice_coef: 0.3802 - val_iou_coef: 0.2353
# Epoch 143/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0946 - dice_coef: 0.4500 - iou_coef: 0.2912 - val_loss: 0.1571 - val_dice_coef: 0.3871 - val_iou_coef: 0.2407
# Epoch 144/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0937 - dice_coef: 0.4565 - iou_coef: 0.2963 - val_loss: 0.1551 - val_dice_coef: 0.3901 - val_iou_coef: 0.2430
# Epoch 145/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0930 - dice_coef: 0.4576 - iou_coef: 0.2977 - val_loss: 0.1558 - val_dice_coef: 0.3796 - val_iou_coef: 0.2350
# Epoch 146/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0927 - dice_coef: 0.4623 - iou_coef: 0.3015 - val_loss: 0.1535 - val_dice_coef: 0.3787 - val_iou_coef: 0.2341
# Epoch 147/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0911 - dice_coef: 0.4707 - iou_coef: 0.3086 - val_loss: 0.1537 - val_dice_coef: 0.4025 - val_iou_coef: 0.2527
# Epoch 148/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0902 - dice_coef: 0.4743 - iou_coef: 0.3116 - val_loss: 0.1564 - val_dice_coef: 0.4135 - val_iou_coef: 0.2616
# Epoch 149/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0907 - dice_coef: 0.4743 - iou_coef: 0.3117 - val_loss: 0.1580 - val_dice_coef: 0.3920 - val_iou_coef: 0.2443
# Epoch 150/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0903 - dice_coef: 0.4738 - iou_coef: 0.3113 - val_loss: 0.1553 - val_dice_coef: 0.4064 - val_iou_coef: 0.2558
# Epoch 151/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0892 - dice_coef: 0.4833 - iou_coef: 0.3193 - val_loss: 0.1623 - val_dice_coef: 0.3914 - val_iou_coef: 0.2444
# Epoch 152/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0882 - dice_coef: 0.4852 - iou_coef: 0.3211 - val_loss: 0.1596 - val_dice_coef: 0.4106 - val_iou_coef: 0.2594
# Epoch 153/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0873 - dice_coef: 0.4941 - iou_coef: 0.3289 - val_loss: 0.1544 - val_dice_coef: 0.3989 - val_iou_coef: 0.2499
# Epoch 154/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0875 - dice_coef: 0.4904 - iou_coef: 0.3260 - val_loss: 0.1522 - val_dice_coef: 0.4049 - val_iou_coef: 0.2545
# Epoch 155/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0857 - dice_coef: 0.4975 - iou_coef: 0.3319 - val_loss: 0.1519 - val_dice_coef: 0.4026 - val_iou_coef: 0.2527
# Epoch 156/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0844 - dice_coef: 0.5062 - iou_coef: 0.3400 - val_loss: 0.1564 - val_dice_coef: 0.4174 - val_iou_coef: 0.2644
# Epoch 157/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0837 - dice_coef: 0.5083 - iou_coef: 0.3418 - val_loss: 0.1594 - val_dice_coef: 0.4121 - val_iou_coef: 0.2605
# Epoch 158/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0846 - dice_coef: 0.5041 - iou_coef: 0.3381 - val_loss: 0.1530 - val_dice_coef: 0.3959 - val_iou_coef: 0.2475
# Epoch 159/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0826 - dice_coef: 0.5123 - iou_coef: 0.3457 - val_loss: 0.1583 - val_dice_coef: 0.4195 - val_iou_coef: 0.2663
# Epoch 160/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0816 - dice_coef: 0.5224 - iou_coef: 0.3545 - val_loss: 0.1572 - val_dice_coef: 0.4072 - val_iou_coef: 0.2562
# Epoch 161/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.0826 - dice_coef: 0.5128 - iou_coef: 0.3459 - val_loss: 0.1597 - val_dice_coef: 0.4197 - val_iou_coef: 0.2663
# Epoch 162/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0798 - dice_coef: 0.5278 - iou_coef: 0.3599 - val_loss: 0.1593 - val_dice_coef: 0.4211 - val_iou_coef: 0.2674
# Epoch 163/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0788 - dice_coef: 0.5347 - iou_coef: 0.3656 - val_loss: 0.1606 - val_dice_coef: 0.4165 - val_iou_coef: 0.2638
# Epoch 164/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0778 - dice_coef: 0.5405 - iou_coef: 0.3714 - val_loss: 0.1604 - val_dice_coef: 0.4199 - val_iou_coef: 0.2665
# Epoch 165/200
# 47/47 [==============================] - 27s 582ms/step - loss: 0.0764 - dice_coef: 0.5454 - iou_coef: 0.3760 - val_loss: 0.1657 - val_dice_coef: 0.4231 - val_iou_coef: 0.2690
# Epoch 166/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0747 - dice_coef: 0.5550 - iou_coef: 0.3854 - val_loss: 0.1671 - val_dice_coef: 0.4167 - val_iou_coef: 0.2638
# Epoch 167/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0755 - dice_coef: 0.5515 - iou_coef: 0.3819 - val_loss: 0.1688 - val_dice_coef: 0.4097 - val_iou_coef: 0.2586
# Epoch 168/200
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0752 - dice_coef: 0.5541 - iou_coef: 0.3839 - val_loss: 0.1679 - val_dice_coef: 0.4114 - val_iou_coef: 0.2597
# Epoch 169/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0731 - dice_coef: 0.5627 - iou_coef: 0.3925 - val_loss: 0.1751 - val_dice_coef: 0.4245 - val_iou_coef: 0.2702
# Epoch 170/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0712 - dice_coef: 0.5713 - iou_coef: 0.4009 - val_loss: 0.1765 - val_dice_coef: 0.4288 - val_iou_coef: 0.2737
# Epoch 171/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0699 - dice_coef: 0.5788 - iou_coef: 0.4083 - val_loss: 0.1912 - val_dice_coef: 0.4296 - val_iou_coef: 0.2745
# Epoch 172/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0695 - dice_coef: 0.5834 - iou_coef: 0.4130 - val_loss: 0.1840 - val_dice_coef: 0.4208 - val_iou_coef: 0.2674
# Epoch 173/200
# 47/47 [==============================] - 27s 565ms/step - loss: 0.0701 - dice_coef: 0.5784 - iou_coef: 0.4084 - val_loss: 0.1823 - val_dice_coef: 0.4168 - val_iou_coef: 0.2642
# Epoch 174/200
# 47/47 [==============================] - 26s 565ms/step - loss: 0.0706 - dice_coef: 0.5790 - iou_coef: 0.4089 - val_loss: 0.1823 - val_dice_coef: 0.4245 - val_iou_coef: 0.2702
# Epoch 175/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0676 - dice_coef: 0.5934 - iou_coef: 0.4231 - val_loss: 0.1886 - val_dice_coef: 0.4188 - val_iou_coef: 0.2657

# %%
plot_training_history(history)

# %%
print('*'*30)
print('Loading saved weights...')
print('*'*30)
model.load_weights('/content/drive/MyDrive/NIDA/Image_analytics/Project/UnetwithMass_200epochs.h5')
# Out:
# ******************************
# Loading saved weights...
# ******************************

# %%
path_test = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/test'
path_mask_test = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/test_labels'

img_test_path = listOfFiles(path_test)
img_test_mask_path = listOfFiles(path_mask_test)


img_test = []
img_test_mask = []

for i in range(len(img_test_path)):
  test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_test.append(test_im)
  img_test_mask.append(mask_test_im)


img_test = np.array(img_test)
img_test = img_test.astype('float32')
img_test /= 255

img_test_mask = np.array(img_test_mask)
img_test_mask = img_test_mask.astype('float32')
img_test_mask /= 255
img_test_mask[img_test_mask > 0.5] = 1
img_test_mask[img_test_mask <= 0.5] = 0


print('*'*30)
print('Evalute model on test data...')
print('*'*30)

eval = model.evaluate(img_test, img_test_mask)
# Out:
# ******************************
# Evalute model on test data...
# ******************************
# 2/2 [==============================] - 4s 2s/step - loss: 0.1118 - dice_coef: 0.5183 - iou_coef: 0.3504

# %%
path_pred = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/Massachusetts_Roads_Dataset/tiff/val'
img_pred_path = listOfFiles(path_pred)
img_pred = []

for i in range(len(img_pred_path)):
  pred_im = cv2.resize(cv2.cvtColor(cv2.imread(img_pred_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_pred.append(pred_im)

img_pred = np.array(img_pred)
img_pred = img_pred.astype('float32')
img_pred /= 255

print('*'*30)
print('Predicting masks on test data...')
print('*'*30)
mask_pred = model.predict(img_pred, verbose=1)
# Out:
# ******************************
# Predicting masks on test data...
# ******************************
# 1/1 [==============================] - 1s 1s/step

# %%
plt.imshow(mask_pred[4])

# %%
plt.imshow(img_pred[4])
