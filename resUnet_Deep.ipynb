# %%
import numpy as np 
import os
import cv2

import keras.backend as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import backend as keras
from keras.metrics import accuracy
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
# %tensorflow_version 2.x

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Create 2 virtual GPUs with 1GB memory each
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=1024),
         tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPU, 2 Logical GPUs

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_logical_devices('GPU')
strategy = tf.distribute.MirroredStrategy(gpus)
with strategy.scope():
  inputs = tf.keras.layers.Input(shape=(1,))
  predictions = tf.keras.layers.Dense(1)(inputs)
  model = tf.keras.models.Model(inputs=inputs, outputs=predictions)
  model.compile(loss='mse',
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.2))
# Out:
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8011660427965312396
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 16154099712
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1745529584887828300
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# xla_global_id: 416903419
# ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou


def res_block(x, nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same', strides=strides[0])(res_path)
    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same', strides=strides[1])(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1), strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)

    res_path = add([shortcut, res_path])
    return res_path


def encoder(x):
    to_decoder = []

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(x)
    main_path = BatchNormalization()(main_path)
    main_path = Activation(activation='relu')(main_path)

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(main_path)

    shortcut = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1))(x)
    shortcut = BatchNormalization()(shortcut)

    main_path = add([shortcut, main_path])
    # first branching to decoder
    to_decoder.append(main_path)

    main_path = res_block(main_path, [128, 128], [(2, 2), (1, 1)])
    to_decoder.append(main_path)

    main_path = res_block(main_path, [256, 256], [(2, 2), (1, 1)])
    to_decoder.append(main_path)

    return to_decoder


def decoder(x, from_encoder):
    main_path = UpSampling2D(size=(2, 2))(x)
    main_path = concatenate([main_path, from_encoder[2]], axis=3)
    main_path = res_block(main_path, [256, 256], [(1, 1), (1, 1)])

    main_path = UpSampling2D(size=(2, 2))(main_path)
    main_path = concatenate([main_path, from_encoder[1]], axis=3)
    main_path = res_block(main_path, [128, 128], [(1, 1), (1, 1)])

    main_path = UpSampling2D(size=(2, 2))(main_path)
    main_path = concatenate([main_path, from_encoder[0]], axis=3)
    main_path = res_block(main_path, [64, 64], [(1, 1), (1, 1)])

    return main_path


def res_unet1(input_shape = (256,256,3)):
    inputs = Input(shape=input_shape)

    to_decoder = encoder(inputs)

    path = res_block(to_decoder[2], [512, 512], [(2, 2), (1, 1)])

    path = decoder(path, from_encoder=to_decoder)

    path = Conv2D(filters=3, kernel_size=(1, 1), activation='sigmoid')(path)
    
    model = Model(inputs=inputs, outputs=path)
    model.compile(optimizer = Adam(learning_rate = 0.002), loss = 'binary_crossentropy', metrics = [dice_coef, iou_coef])
    
    return model

# %%
def listOfFiles(directory, condition):

    x = []

    for root, dirs, files in os.walk(directory):

        for name in files:

            if condition in name:

              filename = os.path.join(root, name)

              y = filename.split('\\')

              x.append(y[0])
            
    x.sort()

    return x

# %%
print('*'*30)
print('Loading and preprocessing train data...')
print('*'*30)

path = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/DeepGlobe_Road_Extraction_Dataset/train'

condiiton_train = '_sat.jpg'
img_train_path = listOfFiles(path, condiiton_train)

condiiton_mask = '_mask.png'
img_train_mask_path = listOfFiles(path, condiiton_mask)
img_train = []
mask_train = []

for i in range(1000):
  train_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_im = cv2.resize(cv2.cvtColor(cv2.imread(img_train_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_train.append(train_im)
  mask_train.append(mask_im)

img_train = np.array(img_train)
img_train = img_train.astype('float32')
img_train /= 255

mask_train = np.array(mask_train)
mask_train = mask_train.astype('float32')
mask_train /= 255
mask_train[mask_train > 0.5] = 1
mask_train[mask_train <= 0.5] = 0

print('*'*30)
print('Complete preprocessing train data...')
print('*'*30)
# Out:
# ******************************
# Loading and preprocessing train data...
# ******************************
# ******************************
# Complete preprocessing train data...
# ******************************

# %%
print('*'*30)
print('Creating and compiling model...')
print('*'*30)
model = res_unet1()
# Out:
# ******************************
# Creating and compiling model...
# ******************************

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  256         ['input_2[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['add[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  73856       ['activation_1[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  8320        ['add[0][0]']
#                                 8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_4[0][0]',
#                                 8)                                'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['add_1[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  33024       ['add_1[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 256)  1024       ['add_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  1180160     ['activation_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  131584      ['add_2[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 512)  0           ['add_3[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'add_2[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 768)  3072       ['concatenate[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 64, 64, 768)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1769728     ['activation_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 256)  196864      ['concatenate[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_8[0][0]']
#
#  add_4 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['add_4[0][0]']
#                                 6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'add_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 38  1536       ['concatenate_1[0][0]']
#  ormalization)                  4)
#
#  activation_9 (Activation)      (None, 128, 128, 38  0           ['batch_normalization_14[0][0]']
#                                 4)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  442496      ['activation_9[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 12  49280       ['concatenate_1[0][0]']
#                                 8)
#
#  activation_10 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 12  512        ['conv2d_17[0][0]']
#  ormalization)                  8)
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 12  147584      ['activation_10[0][0]']
#                                 8)
#
#  add_5 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_16[0][0]',
#                                 8)                                'conv2d_16[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 12  0          ['add_5[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'add[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 19  768        ['concatenate_2[0][0]']
#  ormalization)                  2)
#
#  activation_11 (Activation)     (None, 256, 256, 19  0           ['batch_normalization_17[0][0]']
#                                 2)
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 64  110656      ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  12352       ['concatenate_2[0][0]']
#                                 )
#
#  activation_12 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  36928       ['activation_12[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 256, 256, 64  0           ['batch_normalization_19[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 3)  195         ['add_6[0][0]']
#
# ==================================================================================================
# Total params: 8,233,155
# Trainable params: 8,223,939
# Non-trainable params: 9,216
# __________________________________________________________________________________________________

# %%
def plot_training_history(history):
    """
    Plots model training history 
    """
    fig, (ax_loss, ax_dic, ax_iou) = plt.subplots(1, 3, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_dic.plot(history.epoch, history.history["dice_coef"], label="Train dice")
    ax_dic.plot(history.epoch, history.history["val_dice_coef"], label="Validation dice")
    ax_dic.legend()
    ax_iou.plot(history.epoch, history.history["iou_coef"], label="Train iou")
    ax_iou.plot(history.epoch, history.history["val_iou_coef"], label="Validation iou")
    ax_iou.legend()

# %%
print('*'*30)
print('Fitting model...')
print('*'*30)

epochs = 200
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint(f'resUnetwithDeep_{epochs}epochs.h5', monitor='loss', save_best_only=True)

history =  model.fit(img_train, mask_train, batch_size=15, epochs=epochs, verbose=1, shuffle=True,
          validation_split=0.3,
          callbacks=[model_checkpoint, early_stopping])
# Out:
# ******************************
# Fitting model...
# ******************************
# Epoch 1/200
# 47/47 [==============================] - 47s 651ms/step - loss: 0.2119 - dice_coef: 0.0935 - iou_coef: 0.0418 - val_loss: 12.3912 - val_dice_coef: 0.0082 - val_iou_coef: 0.0040
# Epoch 2/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1638 - dice_coef: 0.1079 - iou_coef: 0.0495 - val_loss: 0.2620 - val_dice_coef: 0.0547 - val_iou_coef: 0.0253
# Epoch 3/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1559 - dice_coef: 0.1192 - iou_coef: 0.0554 - val_loss: 0.2730 - val_dice_coef: 0.0146 - val_iou_coef: 0.0059
# Epoch 4/200
# 47/47 [==============================] - 30s 631ms/step - loss: 0.1535 - dice_coef: 0.1231 - iou_coef: 0.0576 - val_loss: 0.1698 - val_dice_coef: 0.0615 - val_iou_coef: 0.0260
# Epoch 5/200
# 47/47 [==============================] - 28s 594ms/step - loss: 0.1511 - dice_coef: 0.1303 - iou_coef: 0.0635 - val_loss: 0.2587 - val_dice_coef: 0.0363 - val_iou_coef: 0.0122
# Epoch 6/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1503 - dice_coef: 0.1374 - iou_coef: 0.0661 - val_loss: 0.1855 - val_dice_coef: 0.0899 - val_iou_coef: 0.0370
# Epoch 7/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.1467 - dice_coef: 0.1487 - iou_coef: 0.0744 - val_loss: 0.8566 - val_dice_coef: 0.0244 - val_iou_coef: 0.0085
# Epoch 8/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1458 - dice_coef: 0.1595 - iou_coef: 0.0793 - val_loss: 0.3387 - val_dice_coef: 0.0997 - val_iou_coef: 0.0362
# Epoch 9/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1418 - dice_coef: 0.1787 - iou_coef: 0.0924 - val_loss: 0.1516 - val_dice_coef: 0.1383 - val_iou_coef: 0.0656
# Epoch 10/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1324 - dice_coef: 0.2177 - iou_coef: 0.1135 - val_loss: 0.1489 - val_dice_coef: 0.1901 - val_iou_coef: 0.0927
# Epoch 11/200
# 47/47 [==============================] - 28s 594ms/step - loss: 0.1251 - dice_coef: 0.2530 - iou_coef: 0.1365 - val_loss: 0.1480 - val_dice_coef: 0.1351 - val_iou_coef: 0.0607
# Epoch 12/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.1227 - dice_coef: 0.2685 - iou_coef: 0.1449 - val_loss: 0.1504 - val_dice_coef: 0.2449 - val_iou_coef: 0.1239
# Epoch 13/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1155 - dice_coef: 0.3064 - iou_coef: 0.1669 - val_loss: 0.1507 - val_dice_coef: 0.1492 - val_iou_coef: 0.0738
# Epoch 14/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1124 - dice_coef: 0.3248 - iou_coef: 0.1808 - val_loss: 0.1421 - val_dice_coef: 0.1359 - val_iou_coef: 0.0647
# Epoch 15/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.1048 - dice_coef: 0.3608 - iou_coef: 0.2060 - val_loss: 0.1592 - val_dice_coef: 0.1242 - val_iou_coef: 0.0597
# Epoch 16/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1031 - dice_coef: 0.3755 - iou_coef: 0.2146 - val_loss: 0.1199 - val_dice_coef: 0.2286 - val_iou_coef: 0.1266
# Epoch 17/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.1025 - dice_coef: 0.3816 - iou_coef: 0.2210 - val_loss: 0.1507 - val_dice_coef: 0.1341 - val_iou_coef: 0.0678
# Epoch 18/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.0989 - dice_coef: 0.3991 - iou_coef: 0.2322 - val_loss: 0.1474 - val_dice_coef: 0.2510 - val_iou_coef: 0.1401
# Epoch 19/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0930 - dice_coef: 0.4300 - iou_coef: 0.2535 - val_loss: 0.1132 - val_dice_coef: 0.3043 - val_iou_coef: 0.1683
# Epoch 20/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0916 - dice_coef: 0.4420 - iou_coef: 0.2652 - val_loss: 0.1381 - val_dice_coef: 0.2461 - val_iou_coef: 0.1339
# Epoch 21/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0895 - dice_coef: 0.4404 - iou_coef: 0.2651 - val_loss: 0.1064 - val_dice_coef: 0.3879 - val_iou_coef: 0.2246
# Epoch 22/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0872 - dice_coef: 0.4625 - iou_coef: 0.2830 - val_loss: 0.1116 - val_dice_coef: 0.3279 - val_iou_coef: 0.1730
# Epoch 23/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0837 - dice_coef: 0.4832 - iou_coef: 0.3011 - val_loss: 0.0908 - val_dice_coef: 0.4245 - val_iou_coef: 0.2587
# Epoch 24/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.0833 - dice_coef: 0.4870 - iou_coef: 0.3000 - val_loss: 0.1066 - val_dice_coef: 0.3407 - val_iou_coef: 0.1876
# Epoch 25/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0813 - dice_coef: 0.4922 - iou_coef: 0.3069 - val_loss: 0.1387 - val_dice_coef: 0.2791 - val_iou_coef: 0.1702
# Epoch 26/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0789 - dice_coef: 0.5102 - iou_coef: 0.3202 - val_loss: 0.1678 - val_dice_coef: 0.1942 - val_iou_coef: 0.1088
# Epoch 27/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0768 - dice_coef: 0.5249 - iou_coef: 0.3308 - val_loss: 0.1146 - val_dice_coef: 0.3503 - val_iou_coef: 0.2011
# Epoch 28/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0764 - dice_coef: 0.5243 - iou_coef: 0.3323 - val_loss: 0.1341 - val_dice_coef: 0.3453 - val_iou_coef: 0.2016
# Epoch 29/200
# 47/47 [==============================] - 27s 581ms/step - loss: 0.0773 - dice_coef: 0.5226 - iou_coef: 0.3300 - val_loss: 0.1231 - val_dice_coef: 0.3279 - val_iou_coef: 0.1797
# Epoch 30/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.0748 - dice_coef: 0.5304 - iou_coef: 0.3365 - val_loss: 0.1008 - val_dice_coef: 0.4059 - val_iou_coef: 0.2471
# Epoch 31/200
# 47/47 [==============================] - 28s 591ms/step - loss: 0.0742 - dice_coef: 0.5364 - iou_coef: 0.3414 - val_loss: 0.0941 - val_dice_coef: 0.4604 - val_iou_coef: 0.2854
# Epoch 32/200
# 47/47 [==============================] - 28s 590ms/step - loss: 0.0703 - dice_coef: 0.5626 - iou_coef: 0.3626 - val_loss: 0.1030 - val_dice_coef: 0.4206 - val_iou_coef: 0.2600
# Epoch 33/200
# 47/47 [==============================] - 27s 580ms/step - loss: 0.0707 - dice_coef: 0.5539 - iou_coef: 0.3577 - val_loss: 0.1179 - val_dice_coef: 0.3603 - val_iou_coef: 0.2173

# %%
plot_training_history(history)

# %%
print('*'*30)
print('Loading saved weights...')
print('*'*30)
# model.load_weights('/content/drive/MyDrive/NIDA/Image_analytics/Project/resUnetwithDeep_200epochs.h5')

# %%
path_test = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/DeepGlobe_Road_Extraction_Dataset/test'

condition_test = '_sat.jpg'
img_test_path = listOfFiles(path_test, condition_test)

condition_test_mask = '_mask.png'
img_test_mask_path = listOfFiles(path_test, condition_test_mask)


img_test = []
img_test_mask = []

for i in range(len(img_test_path)):
  test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  mask_test_im = cv2.resize(cv2.cvtColor(cv2.imread(img_test_mask_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_test.append(test_im)
  img_test_mask.append(mask_test_im)


img_test = np.array(img_test)
img_test = img_test.astype('float32')
img_test /= 255

img_test_mask = np.array(img_test_mask)
img_test_mask = img_test_mask.astype('float32')
img_test_mask /= 255
img_test_mask[img_test_mask > 0.5] = 1
img_test_mask[img_test_mask <= 0.5] = 0


print('*'*30)
print('Evalute model on test data...')
print('*'*30)

eval = model.evaluate(img_test, img_test_mask)
# Out:
# ******************************
# Evalute model on test data...
# ******************************
# 7/7 [==============================] - 5s 361ms/step - loss: 0.1284 - dice_coef: 0.3661 - iou_coef: 0.2401

# %%
path_pred = '/content/drive/MyDrive/NIDA/Image_analytics/Project/datasets/DeepGlobe_Road_Extraction_Dataset/test_predict'
condition_pred = '_sat.jpg'
img_pred_path = listOfFiles(path_pred, condition_pred)
img_pred = []

for i in range(len(img_pred_path)):
  pred_im = cv2.resize(cv2.cvtColor(cv2.imread(img_pred_path[i]),cv2.COLOR_BGR2RGB), (256, 256))
  img_pred.append(pred_im)

img_pred = np.array(img_pred)
img_pred = img_pred.astype('float32')
img_pred /= 255

print('*'*30)
print('Predicting masks on test data...')
print('*'*30)
mask_pred = model.predict(img_pred, verbose=1)
# Out:
# ******************************
# Predicting masks on test data...
# ******************************
# 35/35 [==============================] - 13s 357ms/step

# %%
plt.imshow(mask_pred[500])

# %%
plt.imshow(img_pred[500])
